# %%
import librosa
import numpy as np
import glob
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import joblib
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import tensorflow as tf

# Define the emotions and observed emotions
emotions = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

observed_emotions = ['neutral', 'calm', 'happy', 'sad', 'fearful', 'surprised']

data_directory = "E:\SER\data\\ravdess"
def extract_feature(data, sr, mfcc=True, chroma=True, mel=True):
    result = np.array([])
    if chroma:
        stft = np.abs(librosa.stft(data))
    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sr, n_mfcc=40).T, axis=0)
        result = np.hstack((result, mfccs))
    if chroma:
        chroma_feature = np.mean(librosa.feature.chroma_stft(S=stft, sr=sr).T, axis=0)
        result = np.hstack((result, chroma_feature))
    if mel:
        mel_feature = np.mean(librosa.feature.melspectrogram(y=data, sr=sr).T, axis=0)
        result = np.hstack((result, mel_feature))
    return result

def noise(data, noise_factor):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    return augmented_data.astype(type(data[0]))

def shift(data, sampling_rate, shift_max, shift_direction):
    shift = np.random.randint(sampling_rate * shift_max)
    if shift_direction == 'right':
        shift = -shift
    elif shift_direction == 'both':
        direction = np.random.randint(0, 2)
        if direction == 1:
            shift = -shift
    augmented_data = np.roll(data, shift)
    if shift > 0:
        augmented_data[:shift] = 0
    else:
        augmented_data[shift:] = 0
    return augmented_data

def load_data(save=False):
    x, y = [], []
    durations = []

    for file in glob.glob(data_directory + "/Actor_*/*.wav"):
        data, sr = librosa.load(file)
        duration = len(data) / sr
        durations.append(duration)
        
        feature = extract_feature(data, sr)
        file_name = os.path.basename(file)
        emotion = emotions[file_name.split("-")[2]]
        
        if emotion in observed_emotions:
            x.append(feature)
            y.append(emotion)

            n_data = noise(data, 0.001)
            n_feature = extract_feature(n_data, sr)
            x.append(n_feature)
            y.append(emotion)

            s_data = shift(data, sr, 0.25, 'right')
            s_feature = extract_feature(s_data, sr)
            x.append(s_feature)
            y.append(emotion)
    
 
    

  
    np.save('Xfinal.npy', np.array(x))
    np.save('yfinal.npy', y)
    # min_duration = min(durations)
    # max_duration = max(durations)
    # print(f"Minimum audio length: {min_duration:.2f} seconds")
    # print(f"Maximum audio length: {max_duration:.2f} seconds")

    return np.array(x), y
    

# Load and process the data
X, y = load_data(save=True)

# %%
X
# Out:
# array([[-7.04823425e+02,  6.53288727e+01, -9.19415855e+00, ...,
#          1.34345183e-16,  1.62977596e-16,  3.77389475e-17],
#        [-4.45094574e+02,  2.10709743e+01,  6.55960560e+00, ...,
#          7.13321861e-05,  6.89793815e-05,  6.78238212e-05],
#        [-7.08801819e+02,  6.61232224e+01, -9.42120075e+00, ...,
#          1.34336342e-16,  1.62974168e-16,  3.77350630e-17],
#        ...,
#        [-5.33215759e+02,  5.07854843e+01, -2.39176464e+01, ...,
#          1.03407571e-12,  1.01320916e-12,  9.97647169e-13],
#        [-4.03522736e+02,  2.37669430e+01, -7.50971651e+00, ...,
#          6.69460060e-05,  7.25114514e-05,  7.23951671e-05],
#        [-5.33193542e+02,  5.07531815e+01, -2.39222736e+01, ...,
#          1.09925599e-12,  1.07700415e-12,  1.06058001e-12]])

# %%
# Convert y to a NumPy array
y = np.array(y)
# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=9)
# Label Encoding
label_encoder = LabelEncoder()
label_encoder.fit(observed_emotions)
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Save the LabelEncoder
joblib.dump(label_encoder, 'label_encoderfinal.pkl')
# Add an extra dimension to the data
XProcessed = np.expand_dims(x_train, axis=2)
XTestProcessed = np.expand_dims(x_test, axis=2)

# %%
import librosa
import numpy as np
import glob
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv1D, Activation, Dropout, MaxPooling1D, Flatten, Dense
from keras.optimizers import RMSprop
import joblib
from sklearn.metrics import classification_report
# Define the model
model = Sequential()

# First Conv1D layer
model.add(Conv1D(64, 5, padding='same', input_shape=(XProcessed.shape[1], 1)))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=4))

# Second Conv1D layer
model.add(Conv1D(128, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=4))

# Third Conv1D layer
model.add(Conv1D(256, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.1))

# Flatten and Dense layers
model.add(Flatten())
model.add(Dense(6))
model.add(Activation('softmax'))

# Compile the model with RMSprop optimizer
opt = RMSprop(learning_rate=0.0005, rho=0.9, epsilon=1e-07)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(XProcessed, y_train_encoded, epochs=200, validation_data=(XTestProcessed, y_test_encoded), batch_size=63)

# Evaluate the model
loss, accuracy = model.evaluate(XTestProcessed, y_test_encoded)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Make predictions and print classification report
y_pred = model.predict(XTestProcessed)
y_pred = np.argmax(y_pred, axis=1)

print(classification_report(y_test_encoded, y_pred, target_names=observed_emotions))
# Out:
# e:\conda\envs\ser\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# e:\conda\envs\ser\lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 180, 64)        │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 180, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 180, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 45, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 45, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 45, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 45, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 11, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 11, 256)        │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 11, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 11, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2816)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │        16,902 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 6)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 222,470 (869.02 KB)
#  Trainable params: 222,470 (869.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.1961 - loss: 6.1126 - val_accuracy: 0.2765 - val_loss: 1.7713
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2591 - loss: 1.8760 - val_accuracy: 0.2525 - val_loss: 1.6318
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3271 - loss: 1.6035 - val_accuracy: 0.3573 - val_loss: 1.4673
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3868 - loss: 1.4762 - val_accuracy: 0.3548 - val_loss: 1.4291
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4310 - loss: 1.4000 - val_accuracy: 0.4975 - val_loss: 1.2954
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4452 - loss: 1.3446 - val_accuracy: 0.4432 - val_loss: 1.3271
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4563 - loss: 1.3132 - val_accuracy: 0.4773 - val_loss: 1.3004
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4772 - loss: 1.2626 - val_accuracy: 0.4684 - val_loss: 1.2919
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5034 - loss: 1.2288 - val_accuracy: 0.5265 - val_loss: 1.2226
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5276 - loss: 1.2043 - val_accuracy: 0.5821 - val_loss: 1.1374
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5481 - loss: 1.1445 - val_accuracy: 0.4874 - val_loss: 1.2264
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5342 - loss: 1.1426 - val_accuracy: 0.5770 - val_loss: 1.0912
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5550 - loss: 1.0926 - val_accuracy: 0.5682 - val_loss: 1.0867
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5889 - loss: 1.0488 - val_accuracy: 0.5909 - val_loss: 1.0432
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6011 - loss: 1.0186 - val_accuracy: 0.6212 - val_loss: 0.9983
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6332 - loss: 0.9588 - val_accuracy: 0.5859 - val_loss: 1.0447
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6461 - loss: 0.9580 - val_accuracy: 0.5593 - val_loss: 1.0879
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6633 - loss: 0.9125 - val_accuracy: 0.6225 - val_loss: 0.9905
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6528 - loss: 0.9095 - val_accuracy: 0.6326 - val_loss: 0.9291
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6726 - loss: 0.8489 - val_accuracy: 0.6528 - val_loss: 0.8943
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6820 - loss: 0.8361 - val_accuracy: 0.6831 - val_loss: 0.8574
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7017 - loss: 0.7953 - val_accuracy: 0.6755 - val_loss: 0.8724
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7182 - loss: 0.7363 - val_accuracy: 0.6970 - val_loss: 0.7989
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7421 - loss: 0.7073 - val_accuracy: 0.6907 - val_loss: 0.8396
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7362 - loss: 0.7033 - val_accuracy: 0.6654 - val_loss: 0.8453
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7438 - loss: 0.6896 - val_accuracy: 0.6944 - val_loss: 0.7946
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7595 - loss: 0.6203 - val_accuracy: 0.6326 - val_loss: 0.9170
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7494 - loss: 0.6696 - val_accuracy: 0.7109 - val_loss: 0.7477
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7645 - loss: 0.6346 - val_accuracy: 0.7323 - val_loss: 0.7364
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7934 - loss: 0.5902 - val_accuracy: 0.7399 - val_loss: 0.7068
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7882 - loss: 0.5676 - val_accuracy: 0.7437 - val_loss: 0.7098
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7989 - loss: 0.5504 - val_accuracy: 0.7677 - val_loss: 0.6581
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8121 - loss: 0.5421 - val_accuracy: 0.7576 - val_loss: 0.6466
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8143 - loss: 0.5065 - val_accuracy: 0.7601 - val_loss: 0.6691
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8212 - loss: 0.4970 - val_accuracy: 0.7449 - val_loss: 0.7526
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8058 - loss: 0.5239 - val_accuracy: 0.7866 - val_loss: 0.6068
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8240 - loss: 0.4836 - val_accuracy: 0.7664 - val_loss: 0.6335
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8354 - loss: 0.4699 - val_accuracy: 0.7588 - val_loss: 0.6531
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8306 - loss: 0.4476 - val_accuracy: 0.7854 - val_loss: 0.6024
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8381 - loss: 0.4395 - val_accuracy: 0.7462 - val_loss: 0.6642
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8526 - loss: 0.4198 - val_accuracy: 0.7790 - val_loss: 0.5896
# Epoch 42/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8525 - loss: 0.4199 - val_accuracy: 0.7967 - val_loss: 0.5994
# Epoch 43/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8557 - loss: 0.4023 - val_accuracy: 0.7828 - val_loss: 0.6047
# Epoch 44/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8489 - loss: 0.4004 - val_accuracy: 0.8131 - val_loss: 0.5261
# Epoch 45/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8668 - loss: 0.3796 - val_accuracy: 0.8043 - val_loss: 0.5868
# Epoch 46/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8728 - loss: 0.3550 - val_accuracy: 0.7967 - val_loss: 0.5636
# Epoch 47/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8798 - loss: 0.3636 - val_accuracy: 0.8093 - val_loss: 0.5418
# Epoch 48/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8697 - loss: 0.3347 - val_accuracy: 0.7942 - val_loss: 0.5642
# Epoch 49/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8741 - loss: 0.3465 - val_accuracy: 0.8270 - val_loss: 0.5273
# Epoch 50/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8908 - loss: 0.3153 - val_accuracy: 0.8157 - val_loss: 0.5337
# Epoch 51/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8816 - loss: 0.3439 - val_accuracy: 0.8182 - val_loss: 0.5421
# Epoch 52/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8873 - loss: 0.2913 - val_accuracy: 0.8258 - val_loss: 0.5291
# Epoch 53/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8837 - loss: 0.3279 - val_accuracy: 0.8535 - val_loss: 0.4771
# Epoch 54/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8951 - loss: 0.2975 - val_accuracy: 0.8384 - val_loss: 0.4832
# Epoch 55/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9061 - loss: 0.2791 - val_accuracy: 0.8131 - val_loss: 0.6036
# Epoch 56/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9021 - loss: 0.2504 - val_accuracy: 0.8346 - val_loss: 0.4936
# Epoch 57/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9084 - loss: 0.2600 - val_accuracy: 0.8472 - val_loss: 0.4727
# Epoch 58/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9070 - loss: 0.2632 - val_accuracy: 0.8535 - val_loss: 0.4710
# Epoch 59/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9132 - loss: 0.2553 - val_accuracy: 0.8295 - val_loss: 0.5150
# Epoch 60/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9197 - loss: 0.2467 - val_accuracy: 0.8396 - val_loss: 0.5233
# Epoch 61/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9205 - loss: 0.2324 - val_accuracy: 0.8460 - val_loss: 0.4764
# Epoch 62/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9186 - loss: 0.2339 - val_accuracy: 0.8548 - val_loss: 0.4714
# Epoch 63/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9273 - loss: 0.2262 - val_accuracy: 0.8712 - val_loss: 0.4418
# Epoch 64/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9135 - loss: 0.2313 - val_accuracy: 0.8611 - val_loss: 0.4617
# Epoch 65/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9275 - loss: 0.2142 - val_accuracy: 0.8460 - val_loss: 0.5040
# Epoch 66/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9282 - loss: 0.1996 - val_accuracy: 0.8598 - val_loss: 0.4860
# Epoch 67/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9310 - loss: 0.1993 - val_accuracy: 0.8561 - val_loss: 0.4881
# Epoch 68/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9235 - loss: 0.2106 - val_accuracy: 0.8485 - val_loss: 0.4863
# Epoch 69/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9269 - loss: 0.2006 - val_accuracy: 0.8725 - val_loss: 0.4168
# Epoch 70/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9177 - loss: 0.2181 - val_accuracy: 0.8889 - val_loss: 0.4024
# Epoch 71/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9435 - loss: 0.1732 - val_accuracy: 0.8586 - val_loss: 0.4511
# Epoch 72/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9385 - loss: 0.1727 - val_accuracy: 0.8598 - val_loss: 0.4738
# Epoch 73/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9389 - loss: 0.1775 - val_accuracy: 0.8725 - val_loss: 0.4397
# Epoch 74/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9491 - loss: 0.1598 - val_accuracy: 0.8548 - val_loss: 0.4957
# Epoch 75/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9431 - loss: 0.1730 - val_accuracy: 0.8712 - val_loss: 0.4632
# Epoch 76/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9507 - loss: 0.1525 - val_accuracy: 0.8750 - val_loss: 0.4168
# Epoch 77/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9467 - loss: 0.1516 - val_accuracy: 0.8573 - val_loss: 0.4501
# Epoch 78/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9420 - loss: 0.1512 - val_accuracy: 0.8725 - val_loss: 0.4557
# Epoch 79/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9454 - loss: 0.1604 - val_accuracy: 0.8876 - val_loss: 0.4034
# Epoch 80/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9566 - loss: 0.1361 - val_accuracy: 0.8813 - val_loss: 0.4190
# Epoch 81/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9552 - loss: 0.1291 - val_accuracy: 0.8712 - val_loss: 0.4287
# Epoch 82/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9505 - loss: 0.1526 - val_accuracy: 0.8573 - val_loss: 0.4707
# Epoch 83/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9470 - loss: 0.1421 - val_accuracy: 0.8737 - val_loss: 0.4515
# Epoch 84/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9558 - loss: 0.1178 - val_accuracy: 0.8826 - val_loss: 0.4237
# Epoch 85/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9578 - loss: 0.1257 - val_accuracy: 0.8864 - val_loss: 0.4013
# Epoch 86/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9668 - loss: 0.1198 - val_accuracy: 0.8737 - val_loss: 0.4525
# Epoch 87/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9644 - loss: 0.1107 - val_accuracy: 0.8927 - val_loss: 0.4289
# Epoch 88/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9724 - loss: 0.0973 - val_accuracy: 0.8598 - val_loss: 0.4807
# Epoch 89/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9614 - loss: 0.1096 - val_accuracy: 0.8889 - val_loss: 0.4118
# Epoch 90/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9621 - loss: 0.1285 - val_accuracy: 0.8624 - val_loss: 0.5022
# Epoch 91/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9604 - loss: 0.1394 - val_accuracy: 0.8788 - val_loss: 0.4098
# Epoch 92/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9610 - loss: 0.1169 - val_accuracy: 0.8801 - val_loss: 0.4266
# Epoch 93/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9516 - loss: 0.1283 - val_accuracy: 0.8763 - val_loss: 0.4602
# Epoch 94/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9671 - loss: 0.1059 - val_accuracy: 0.8851 - val_loss: 0.4278
# Epoch 95/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9627 - loss: 0.1026 - val_accuracy: 0.8826 - val_loss: 0.4377
# Epoch 96/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9652 - loss: 0.1059 - val_accuracy: 0.8775 - val_loss: 0.4725
# Epoch 97/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9561 - loss: 0.1110 - val_accuracy: 0.8712 - val_loss: 0.5237
# Epoch 98/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9601 - loss: 0.1165 - val_accuracy: 0.8838 - val_loss: 0.4590
# Epoch 99/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9717 - loss: 0.0800 - val_accuracy: 0.8775 - val_loss: 0.4454
# Epoch 100/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9684 - loss: 0.0939 - val_accuracy: 0.8876 - val_loss: 0.4398
# Epoch 101/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9733 - loss: 0.0838 - val_accuracy: 0.8914 - val_loss: 0.3909
# Epoch 102/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9733 - loss: 0.0871 - val_accuracy: 0.8838 - val_loss: 0.4316
# Epoch 103/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9753 - loss: 0.0791 - val_accuracy: 0.8864 - val_loss: 0.5130
# Epoch 104/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9775 - loss: 0.0737 - val_accuracy: 0.8788 - val_loss: 0.4468
# Epoch 105/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9778 - loss: 0.0683 - val_accuracy: 0.8801 - val_loss: 0.4851
# Epoch 106/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9724 - loss: 0.0826 - val_accuracy: 0.8927 - val_loss: 0.4532
# Epoch 107/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9685 - loss: 0.0829 - val_accuracy: 0.8838 - val_loss: 0.4373
# Epoch 108/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9728 - loss: 0.0868 - val_accuracy: 0.8927 - val_loss: 0.4540
# Epoch 109/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9836 - loss: 0.0558 - val_accuracy: 0.8801 - val_loss: 0.4663
# Epoch 110/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9745 - loss: 0.0782 - val_accuracy: 0.8876 - val_loss: 0.4350
# Epoch 111/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9762 - loss: 0.0798 - val_accuracy: 0.8952 - val_loss: 0.4103
# Epoch 112/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9809 - loss: 0.0632 - val_accuracy: 0.8813 - val_loss: 0.4339
# Epoch 113/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9831 - loss: 0.0653 - val_accuracy: 0.8902 - val_loss: 0.4284
# Epoch 114/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9723 - loss: 0.0724 - val_accuracy: 0.8763 - val_loss: 0.4716
# Epoch 115/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9764 - loss: 0.0633 - val_accuracy: 0.8750 - val_loss: 0.4938
# Epoch 116/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9769 - loss: 0.0752 - val_accuracy: 0.8750 - val_loss: 0.5130
# Epoch 117/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9796 - loss: 0.0628 - val_accuracy: 0.8813 - val_loss: 0.4829
# Epoch 118/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9846 - loss: 0.0482 - val_accuracy: 0.8826 - val_loss: 0.4968
# Epoch 119/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9819 - loss: 0.0502 - val_accuracy: 0.8750 - val_loss: 0.5527
# Epoch 120/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9747 - loss: 0.0733 - val_accuracy: 0.8788 - val_loss: 0.4415
# Epoch 121/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9742 - loss: 0.0787 - val_accuracy: 0.8851 - val_loss: 0.4471
# Epoch 122/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9845 - loss: 0.0479 - val_accuracy: 0.8826 - val_loss: 0.4516
# Epoch 123/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9780 - loss: 0.0658 - val_accuracy: 0.8788 - val_loss: 0.4962
# Epoch 124/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9781 - loss: 0.0905 - val_accuracy: 0.8864 - val_loss: 0.4514
# Epoch 125/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9874 - loss: 0.0523 - val_accuracy: 0.8889 - val_loss: 0.4631
# Epoch 126/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9779 - loss: 0.0683 - val_accuracy: 0.8851 - val_loss: 0.5074
# Epoch 127/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9839 - loss: 0.0514 - val_accuracy: 0.8725 - val_loss: 0.5142
# Epoch 128/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9837 - loss: 0.0549 - val_accuracy: 0.9028 - val_loss: 0.4554
# Epoch 129/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9843 - loss: 0.0460 - val_accuracy: 0.8737 - val_loss: 0.5236
# Epoch 130/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9869 - loss: 0.0395 - val_accuracy: 0.8914 - val_loss: 0.4788
# Epoch 131/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9835 - loss: 0.0511 - val_accuracy: 0.8826 - val_loss: 0.5219
# Epoch 132/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9804 - loss: 0.0470 - val_accuracy: 0.8914 - val_loss: 0.5197
# Epoch 133/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9843 - loss: 0.0455 - val_accuracy: 0.8826 - val_loss: 0.5153
# Epoch 134/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9851 - loss: 0.0419 - val_accuracy: 0.8952 - val_loss: 0.4303
# Epoch 135/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9854 - loss: 0.0451 - val_accuracy: 0.8813 - val_loss: 0.5099
# Epoch 136/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9897 - loss: 0.0379 - val_accuracy: 0.8864 - val_loss: 0.4828
# Epoch 137/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9848 - loss: 0.0491 - val_accuracy: 0.8838 - val_loss: 0.5176
# Epoch 138/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9850 - loss: 0.0395 - val_accuracy: 0.8737 - val_loss: 0.5161
# Epoch 139/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9818 - loss: 0.0474 - val_accuracy: 0.8851 - val_loss: 0.5249
# Epoch 140/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9805 - loss: 0.0586 - val_accuracy: 0.8939 - val_loss: 0.4565
# Epoch 141/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9899 - loss: 0.0389 - val_accuracy: 0.8813 - val_loss: 0.4902
# Epoch 142/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9912 - loss: 0.0370 - val_accuracy: 0.8775 - val_loss: 0.5884
# Epoch 143/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9812 - loss: 0.0515 - val_accuracy: 0.8813 - val_loss: 0.5195
# Epoch 144/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9857 - loss: 0.0328 - val_accuracy: 0.8952 - val_loss: 0.4701
# Epoch 145/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9892 - loss: 0.0350 - val_accuracy: 0.8763 - val_loss: 0.5450
# Epoch 146/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9861 - loss: 0.0413 - val_accuracy: 0.8876 - val_loss: 0.4908
# Epoch 147/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9875 - loss: 0.0396 - val_accuracy: 0.8851 - val_loss: 0.5103
# Epoch 148/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9868 - loss: 0.0345 - val_accuracy: 0.8687 - val_loss: 0.6149
# Epoch 149/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9881 - loss: 0.0414 - val_accuracy: 0.8952 - val_loss: 0.4881
# Epoch 150/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9868 - loss: 0.0354 - val_accuracy: 0.8838 - val_loss: 0.4948
# Epoch 151/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9886 - loss: 0.0345 - val_accuracy: 0.8864 - val_loss: 0.5213
# Epoch 152/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9898 - loss: 0.0305 - val_accuracy: 0.8826 - val_loss: 0.5598
# Epoch 153/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9841 - loss: 0.0409 - val_accuracy: 0.8826 - val_loss: 0.5117
# Epoch 154/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9849 - loss: 0.0401 - val_accuracy: 0.8977 - val_loss: 0.5081
# Epoch 155/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9895 - loss: 0.0298 - val_accuracy: 0.8864 - val_loss: 0.4858
# Epoch 156/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9883 - loss: 0.0346 - val_accuracy: 0.8902 - val_loss: 0.4863
# Epoch 157/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9895 - loss: 0.0297 - val_accuracy: 0.8838 - val_loss: 0.5254
# Epoch 158/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9893 - loss: 0.0366 - val_accuracy: 0.8826 - val_loss: 0.4709
# Epoch 159/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9909 - loss: 0.0379 - val_accuracy: 0.8927 - val_loss: 0.4768
# Epoch 160/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9895 - loss: 0.0311 - val_accuracy: 0.8788 - val_loss: 0.5080
# Epoch 161/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9914 - loss: 0.0298 - val_accuracy: 0.8813 - val_loss: 0.4938
# Epoch 162/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9870 - loss: 0.0354 - val_accuracy: 0.8826 - val_loss: 0.4828
# Epoch 163/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9954 - loss: 0.0184 - val_accuracy: 0.8788 - val_loss: 0.5616
# Epoch 164/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9877 - loss: 0.0328 - val_accuracy: 0.8801 - val_loss: 0.5115
# Epoch 165/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9916 - loss: 0.0261 - val_accuracy: 0.8788 - val_loss: 0.5480
# Epoch 166/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9915 - loss: 0.0264 - val_accuracy: 0.8952 - val_loss: 0.4624
# Epoch 167/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9952 - loss: 0.0147 - val_accuracy: 0.8851 - val_loss: 0.5378
# Epoch 168/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9896 - loss: 0.0353 - val_accuracy: 0.8725 - val_loss: 0.6215
# Epoch 169/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9901 - loss: 0.0360 - val_accuracy: 0.8838 - val_loss: 0.5475
# Epoch 170/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9911 - loss: 0.0278 - val_accuracy: 0.8952 - val_loss: 0.5072
# Epoch 171/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9906 - loss: 0.0295 - val_accuracy: 0.8889 - val_loss: 0.5385
# Epoch 172/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9879 - loss: 0.0371 - val_accuracy: 0.8775 - val_loss: 0.5419
# Epoch 173/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9911 - loss: 0.0254 - val_accuracy: 0.8889 - val_loss: 0.5435
# Epoch 174/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9937 - loss: 0.0197 - val_accuracy: 0.8990 - val_loss: 0.4535
# Epoch 175/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9837 - loss: 0.0393 - val_accuracy: 0.8712 - val_loss: 0.6189
# Epoch 176/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9939 - loss: 0.0289 - val_accuracy: 0.8851 - val_loss: 0.5746
# Epoch 177/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9823 - loss: 0.0598 - val_accuracy: 0.8952 - val_loss: 0.5061
# Epoch 178/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9927 - loss: 0.0278 - val_accuracy: 0.8965 - val_loss: 0.5716
# Epoch 179/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9897 - loss: 0.0263 - val_accuracy: 0.8801 - val_loss: 0.6112
# Epoch 180/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9898 - loss: 0.0347 - val_accuracy: 0.8965 - val_loss: 0.5338
# Epoch 181/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9894 - loss: 0.0292 - val_accuracy: 0.8813 - val_loss: 0.5662
# Epoch 182/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9927 - loss: 0.0210 - val_accuracy: 0.8977 - val_loss: 0.5722
# Epoch 183/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9942 - loss: 0.0228 - val_accuracy: 0.8902 - val_loss: 0.5457
# Epoch 184/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9924 - loss: 0.0372 - val_accuracy: 0.8876 - val_loss: 0.5660
# Epoch 185/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9828 - loss: 0.0474 - val_accuracy: 0.8927 - val_loss: 0.5297
# Epoch 186/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9927 - loss: 0.0238 - val_accuracy: 0.9066 - val_loss: 0.4552
# Epoch 187/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9956 - loss: 0.0163 - val_accuracy: 0.8914 - val_loss: 0.5260
# Epoch 188/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9915 - loss: 0.0203 - val_accuracy: 0.8889 - val_loss: 0.5003
# Epoch 189/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9881 - loss: 0.0420 - val_accuracy: 0.8914 - val_loss: 0.5356
# Epoch 190/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9913 - loss: 0.0261 - val_accuracy: 0.8902 - val_loss: 0.5430
# Epoch 191/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9909 - loss: 0.0280 - val_accuracy: 0.8851 - val_loss: 0.5773
# Epoch 192/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.8977 - val_loss: 0.5266
# Epoch 193/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9872 - loss: 0.0325 - val_accuracy: 0.8952 - val_loss: 0.5059
# Epoch 194/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9894 - loss: 0.0271 - val_accuracy: 0.8889 - val_loss: 0.5582
# Epoch 195/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9918 - loss: 0.0332 - val_accuracy: 0.8902 - val_loss: 0.5685
# Epoch 196/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9906 - loss: 0.0310 - val_accuracy: 0.8977 - val_loss: 0.5094
# Epoch 197/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9883 - loss: 0.0312 - val_accuracy: 0.8876 - val_loss: 0.6049
# Epoch 198/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9927 - loss: 0.0205 - val_accuracy: 0.8914 - val_loss: 0.5758
# Epoch 199/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9882 - loss: 0.0304 - val_accuracy: 0.8775 - val_loss: 0.6147
# Epoch 200/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9864 - loss: 0.0435 - val_accuracy: 0.9015 - val_loss: 0.5364
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.4542
# Test Loss: 0.5364
# Test Accuracy: 0.9015
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#      neutral       0.90      0.90      0.90       135
#         calm       0.93      0.87      0.90       155
#        happy       0.92      0.95      0.93       138
#          sad       0.82      0.91      0.86        75
#      fearful       0.92      0.84      0.88       134
#    surprised       0.89      0.94      0.92       155
#
#     accuracy                           0.90       792
#    macro avg       0.90      0.90      0.90       792
# weighted avg       0.90      0.90      0.90       792

# %%
model.save('emotion_recognition_modelv3.h5')
print("Model and weights saved to 'emotion_recognition_modelv3.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and weights saved to 'emotion_recognition_modelv3.h5'
